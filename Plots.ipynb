# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
from matplotlib.ticker import MultipleLocator, FormatStrFormatter,  AutoMinorLocator

# %%
# use this to setup the parameters...
mpl.rcParams['xtick.labelsize'] = 20
mpl.rcParams['ytick.labelsize'] = 20
mpl.rcParams['font.size'] = 22
mpl.rcParams['figure.figsize'] =  10,6
mpl.rcParams['axes.labelsize'] = 25
mpl.rcParams['mathtext.fontset'] = 'stix'
mpl.rcParams['font.family'] = 'STIXGeneral'
mpl.rcParams['axes.linewidth'] = 2.5

# %%
import numpy as np

# %%
def sigmoid(z):
    return 1/(1 + np.exp(-z))

# %%
x = np.linspace(0, 1, num=50)

# %%
# %matplotlib notebook
from ipywidgets import *
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 1, num=50)

def f(x, W, B):
    return sigmoid(W*x - B)

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
line, = ax.plot(x, f(x, W=10, B=5))

def update(W = 1, B = 5):
    line.set_ydata(f(x,W,B))
    fig.canvas.draw_idle()
    
interact(update, W = (0,1000,50), B = (0,500,50));
# Out:
# <img src="data:image/png;base64,..." width="432">
# interactive(children=(IntSlider(value=1, description='W', max=1000, step=50), IntSlider(value=5, description='…

# %%
# %matplotlib inline

# %%
plt.plot(x,y)

# %%
# %matplotlib notebook

x = np.linspace(0, 1, num=50)

def f(x, a):
    return a*sigmoid(1000*x - 300) - a*sigmoid(1000*x - 400)

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
line, = ax.plot(x, f(x, a=1))

def update(a = 1):
    line.set_ydata(f(x,a))
    fig.canvas.draw_idle()
    
interact(update, a = (0,1,0.1));
# Out:
# <img src="data:image/png;base64,..." width="432">
# interactive(children=(FloatSlider(value=1.0, description='a', max=1.0), Output()), _dom_classes=('widget-inter…

# %%
def f(x):
    return sigmoid(1000*x - 300) - sigmoid(1000*x - 400) + 0.7*sigmoid(1000*x - 400) - 0.7*sigmoid(1000*x - 500)

# %%
y = [f(r) for r in x]

# %%
# %matplotlib inline

# %%
plt.plot(x,y)
